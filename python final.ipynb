# %%
#Importing packages
import scipy
import numpy
import matplotlib
import pandas
import matplotlib.pyplot as plt

# %%
# found a dataset
# Load dataset
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/iris.csv"
names = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'class']
dataset = pandas.read_csv(url, names=names)

# %%
#make scatter plots
dataset.plot.scatter('sepal-length', 'sepal-width', s=None, c=None)
dataset.plot.scatter('petal-length', 'petal-width', s=None, c=None)

# %%
#make scatter plot for petals and save it
fig = dataset.plot.scatter('petal-length', 'petal-width', s=None, c=None)
fig.savefig('plot.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-c0910295e07e> in <module>
#       1 #make scatter plot for petals and save it
#       2 fig = dataset.plot.scatter('petal-length', 'petal-width', s=None, c=None)
# ----> 3 fig.savefig('plot.png')
#
# AttributeError: 'AxesSubplot' object has no attribute 'savefig'
